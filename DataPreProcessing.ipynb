# %% [markdown]
# IMPORT LIBRARIES & DATASET
#
# The major libraries that are useful in PreProcessing are Pandas, Numpy, Seaborn and Matplotlib. Followed by this we would import the dataset

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Importing the dataset
dataset = pd.read_csv('diabetes.csv')

# %% [markdown]
# VIEWING THE DATASET
#
# Prior to conducting any analysis, it is essential to gain a comprehensive understanding of the dataset's structure and identify any significant inconsistencies within it. These inconsistencies could potentially pose significant obstacles during the analysis process.

# %%
#Viewing the dataset
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#Viewing the first 5 rows of the dataset
dataset.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Viewing the bottom 5 rows of the dataset
dataset.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#The Number of rows and columns in the dataset
dataset.shape
# Out:
# (768, 9)

# %%
#Identifying the datatype of each features in the dataset
dataset.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#Statistical details on the dataset
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# MISSING VALUES

# %%
#The number of missing values for each columnin the dataset
dataset.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#The percentage of missing values for each columns in the dataset
dataset.isna().sum()/len(dataset)*100
# Out:
# Pregnancies                 0.0
# Glucose                     0.0
# BloodPressure               0.0
# SkinThickness               0.0
# Insulin                     0.0
# BMI                         0.0
# DiabetesPedigreeFunction    0.0
# Age                         0.0
# Outcome                     0.0
# dtype: float64

# %%
#Total Missing values in the dataset
missing_values = dataset.isnull().sum().sum()
total_values = dataset.size

percentage_missing = (missing_values / total_values) * 100

print(f"Percentage of missing values: {percentage_missing:.2f}%")
# Out:
# Percentage of missing values: 0.00%

# %%
#Percentage missing values per column
percent_missing_per_column = (dataset.isnull().sum() / len(dataset)) * 100
percent_missing_per_column = percent_missing_per_column.astype(str) + '%'

print("Percentage of missing values :")
print(percent_missing_per_column)
# Out:
# Percentage of missing values :
# Pregnancies                 0.0%
# Glucose                     0.0%
# BloodPressure               0.0%
# SkinThickness               0.0%
# Insulin                     0.0%
# BMI                         0.0%
# DiabetesPedigreeFunction    0.0%
# Age                         0.0%
# Outcome                     0.0%
# dtype: object

# %% [markdown]
# CORRELATION
#
# Correlation is the statistical measue that quantifies the strength and linear relationship between two variables. A correlation of -1 or Negative correlation indicates that as one variable increases, the other decreases in a perfectly linear fashion. A correlation of +1 or Positive Correlaion indicates that as one variable increases, the other also increases in a perfectly linear fashion. A correlation of 0 indicates no linear relationship between the variables. In other words, they are not associated in a linear manner.

# %%
#A heatmap to identify the coreelation between two variables
plt.figure(figsize =(20,18))
sns.heatmap(dataset.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# OUTLIERS
#
# Outliers are data points or observations that significantly deviate from the majority of the data in a dataset. In other words, outliers are values that are unusual or different from the typical pattern or distribution of data points within a dataset. Outliers can be exceptionally high or low values and are often much farther away from the central tendency (such as the mean or median) than most other data points.

# %%
# %matplotlib inline

# %%
# Plotting boxplot to identify outliers
plt.figure(figsize =(12,10))
sns.boxplot(data=dataset)
# Out:
# <Axes: >

# %%
#The function removes the outliers with the nearest value among the upper limit and lower limit
def remove_outliers(col):
    Q1, Q3 = np.percentile(col, [25, 75])
    IQR = Q3 - Q1
    upper_limit = Q3 + (1.5 * IQR)  # You can adjust the multiplier here (e.g., 1.5)
    lower_limit = Q1 - (1.5 * IQR)  # You can adjust the multiplier here (e.g., 1.5)
    col = np.where(col > upper_limit, upper_limit, col)
    col = np.where(col < lower_limit, lower_limit, col)
    return col

print("Shape of the data Before Outliers:", dataset.shape)

# Iterate through columns and remove outliers
for col in ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']:
    dataset[col] = remove_outliers(dataset[col])

print("Shape of the data After Outliers:", dataset.shape)
# Out:
# Shape of the data Before Outliers: (768, 9)
# Shape of the data After Outliers: (768, 9)

# %%
#Boxplot after treating outliers
plt.figure(figsize =(12,10))
sns.boxplot(data=dataset)
# Out:
# <Axes: >

# %% [markdown]
# DISTRIBUTION
#
# The distribution of data points in a dataset signifies how the values or observations are spread or arranged across different possible values. It provides important information about the underlying patterns, characteristics, and properties of the data. Analyzing the distribution of data can help you understand key aspects of your dataset, including central tendency, variability, and the presence of outliers.

# %%
#Distribution of Feature1 - Pregnancies
plt.figure(figsize=(10,6))
sns.set(style = 'whitegrid')
sns.distplot(dataset['Pregnancies'])
plt.title('Distribution of Pregnanacies', fontsize = 20)
# Out:
# /var/folders/v5/bqkwp7t51m345dvr6ppytt240000gn/T/ipykernel_9884/3538875299.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Pregnancies'])
# Text(0.5, 1.0, 'Distribution of Pregnanacies')

# %%
#Distribution of Feature1 - Glucose
plt.figure(figsize=(10,6))
sns.set(style = 'whitegrid')
sns.distplot(dataset['Glucose'])
plt.title('Distribution of Glucose', fontsize = 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Distribution of Feature1 - Glucose
# ----> 2 plt.figure(figsize=(10,6))
#       3 sns.set(style = 'whitegrid')
#       4 sns.distplot(dataset['Glucose'])
#
# NameError: name 'plt' is not defined

# %%
#Distribution of Feature1 - BloodPressure
plt.figure(figsize=(10,6))
sns.set(style = 'whitegrid')
sns.distplot(dataset['BloodPressure'])
plt.title('Distribution of BloodPressure', fontsize = 20)
# Out:
# /var/folders/v5/bqkwp7t51m345dvr6ppytt240000gn/T/ipykernel_9884/3222134815.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['BloodPressure'])
# Text(0.5, 1.0, 'Distribution of BloodPressure')

# %%
#Distribution of Feature1 - SkinThickness
plt.figure(figsize=(10,6))
sns.set(style = 'whitegrid')
sns.distplot(dataset['SkinThickness'])
plt.title('Distribution of SkinThickness', fontsize = 20)
# Out:
# /var/folders/v5/bqkwp7t51m345dvr6ppytt240000gn/T/ipykernel_9884/3219393908.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['SkinThickness'])
# Text(0.5, 1.0, 'Distribution of SkinThickness')

# %%
#Distribution of Feature1 - Insulin
plt.figure(figsize=(10,6))
sns.set(style = 'whitegrid')
sns.distplot(dataset['Insulin'])
plt.title('Distribution of Insulin', fontsize = 20)
# Out:
# /var/folders/v5/bqkwp7t51m345dvr6ppytt240000gn/T/ipykernel_9884/2571134262.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Insulin'])
# Text(0.5, 1.0, 'Distribution of Insulin')

# %%
#Distribution of Feature1 - BMI
plt.figure(figsize=(10,6))
sns.set(style = 'whitegrid')
sns.distplot(dataset['BMI'])
plt.title('Distribution of BMI', fontsize = 20)
# Out:
# /var/folders/v5/bqkwp7t51m345dvr6ppytt240000gn/T/ipykernel_9793/2502493042.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['BMI'])
# Text(0.5, 1.0, 'Distribution of BMI')

# %%
#Distribution of Feature1 - DiabetesPedigreeFunction
plt.figure(figsize=(10,6))
sns.set(style = 'whitegrid')
sns.distplot(dataset['DiabetesPedigreeFunction'])
plt.title('Distribution of DiabetesPedigreeFunction', fontsize = 20)
# Out:
# /var/folders/v5/bqkwp7t51m345dvr6ppytt240000gn/T/ipykernel_9793/2053510017.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['DiabetesPedigreeFunction'])
# Text(0.5, 1.0, 'Distribution of DiabetesPedigreeFunction')
